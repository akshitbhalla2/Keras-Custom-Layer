# %% [markdown]
# # Custom Layers in Keras

# %% [markdown]
# # Task 1: Importing Libraries

# %%
import tensorflow as tf
import utils
import matplotlib.pyplot as plt
# %matplotlib inline

print('TensorFlow Version:', tf.__version__)
# Out:
# TensorFlow Version: 2.0.0

# %% [markdown]
# # Task 2: Import and Visualize Dataset

# %%
(x_train, y_train), (x_test, y_test) = utils.load_data()

utils.plot_random_examples(x_train, y_train).show()

# %% [markdown]
# # Task 3: Creating a Custom Layer

# %%
class ParametricRelu(tf.keras.layers.Layer):
    def __init__(self, **kwargs):
        super(ParametricRelu, self).__init__(**kwargs)
    
    def build(self, input_shape):
        self.alpha = self.add_weight(
            name='minimum', 
            shape=(1,),
            initializer='zeros',
            trainable=True
        )
        super(ParametricRelu, self).build(input_shape)
    
    def call(self, x):
        return tf.maximum(0., x) + self.alpha * tf.minimum(0., x)

# %% [markdown]
# # Task 4: Creating the Model

# %%
def create_model(use_prelu=True):
    model = tf.keras.models.Sequential()
    model.add(tf.keras.layers.Dense(64, input_shape=(784,)))
    if not use_prelu:
        model.add(tf.keras.layers.ReLU())
    else:
        model.add(ParametricRelu())
    model.add(tf.keras.layers.Dense(10, activation='softmax'))
    model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
    return model

model = create_model()
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 64)                50240
# _________________________________________________________________
# parametric_relu (ParametricR (None, 64)                1
# _________________________________________________________________
# dense_1 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,891
# Trainable params: 50,891
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # Task 5: Model Training

# %%
print('Initial alpha:', model.layers[1].get_weights())

h = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=5
)

print('Final alpha:', model.layers[1].get_weights())
# Out:
# Initial alpha: [array([0.], dtype=float32)]
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 5s 79us/sample - loss: 0.3001 - accuracy: 0.9154 - val_loss: 0.1641 - val_accuracy: 0.9507
# Epoch 2/5
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.1251 - accuracy: 0.9640 - val_loss: 0.1100 - val_accuracy: 0.9684
# Epoch 3/5
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0877 - accuracy: 0.9738 - val_loss: 0.0968 - val_accuracy: 0.9707
# Epoch 4/5
# 60000/60000 [==============================] - 3s 52us/sample - loss: 0.0686 - accuracy: 0.9795 - val_loss: 0.0919 - val_accuracy: 0.9725
# Epoch 5/5
# 60000/60000 [==============================] - 3s 51us/sample - loss: 0.0548 - accuracy: 0.9827 - val_loss: 0.0970 - val_accuracy: 0.9733
# Final alpha: [array([-0.9510322], dtype=float32)]

# %%
utils.plot_results(h).show()

# %% [markdown]
# # Task 6: Comparison with ReLU

# %%
model = create_model(use_prelu=False)
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_2 (Dense)              (None, 64)                50240
# _________________________________________________________________
# re_lu (ReLU)                 (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                650
# =================================================================
# Total params: 50,890
# Trainable params: 50,890
# Non-trainable params: 0
# _________________________________________________________________

# %%
h = model.fit(
    x_train, y_train,
    validation_data=(x_test, y_test),
    epochs=5
)
# Out:
# Train on 60000 samples, validate on 10000 samples
# Epoch 1/5
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.2989 - accuracy: 0.9146 - val_loss: 0.1701 - val_accuracy: 0.9491
# Epoch 2/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1402 - accuracy: 0.9597 - val_loss: 0.1182 - val_accuracy: 0.9648
# Epoch 3/5
# 60000/60000 [==============================] - 3s 53us/sample - loss: 0.1000 - accuracy: 0.9701 - val_loss: 0.0984 - val_accuracy: 0.9692
# Epoch 4/5
# 60000/60000 [==============================] - 3s 50us/sample - loss: 0.0791 - accuracy: 0.9758 - val_loss: 0.0869 - val_accuracy: 0.9726
# Epoch 5/5
# 60000/60000 [==============================] - 3s 57us/sample - loss: 0.0642 - accuracy: 0.9804 - val_loss: 0.0844 - val_accuracy: 0.9742

# %%
utils.plot_results(h).show()
